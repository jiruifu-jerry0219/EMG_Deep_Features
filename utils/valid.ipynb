# %% [markdown]
# ### Validation of reading the 'MAT' file

# %%
import os
import scipy.io as sio
import numpy as np
from collections import defaultdict

# %%
path1 = '/home/jerry/Documents/BME/Deep Feature/EMG/mat/train/'

# %%
x_train = np.zeros((300, 16))

# %%
train = defaultdict(list)

# %%
root = sorted(os.listdir(path1))
#create an empty dictionay to save the train data
keyList = [1, 2, 3, 4, 5, 5]
train = {key: [] for key in keyList}

cont = 1
for i in range(len(root)):
    train_path = path1 + root[i]
    print(train_path)
    for files in sorted(os.listdir(train_path)):
        print(train_path+'/' + files)
        EMG = sio.loadmat(train_path+'/' + files)
        data = EMG['sampleEMG']
        train[list(train)[i]].append(data)
# Out:
# /home/jerry/Documents/BME/Deep Feature/EMG/mat/train/1
# /home/jerry/Documents/BME/Deep Feature/EMG/mat/train/1/1.mat
# /home/jerry/Documents/BME/Deep Feature/EMG/mat/train/1/10.mat
# /home/jerry/Documents/BME/Deep Feature/EMG/mat/train/1/100.mat
# /home/jerry/Documents/BME/Deep Feature/EMG/mat/train/1/101.mat
# /home/jerry/Documents/BME/Deep Feature/EMG/mat/train/1/102.mat
# /home/jerry/Documents/BME/Deep Feature/EMG/mat/train/1/103.mat
# /home/jerry/Documents/BME/Deep Feature/EMG/mat/train/1/104.mat
# /home/jerry/Documents/BME/Deep Feature/EMG/mat/train/1/105.mat
# /home/jerry/Documents/BME/Deep Feature/EMG/mat/train/1/106.mat
# /home/jerry/Documents/BME/Deep Feature/EMG/mat/train/1/107.mat
# /home/jerry/Documents/BME/Deep Feature/EMG/mat/train/1/108.mat
# /home/jerry/Documents/BME/Deep Feature/EMG/mat/train/1/109.mat
# /home/jerry/Documents/BME/Deep Feature/EMG/mat/train/1/11.mat
# /home/jerry/Documents/BME/Deep Feature/EMG/mat/train/1/110.mat
# ...

# %%
type(keyList)
a = '123'

# %%
assert type(keyList) == list, 'abc'
assert type(a) == str, 'abe'

# %%
type(a)
# Out:
# str

# %%
train[1][0].shape
# Out:
# (300, 16)

# %%
root = os.listdir(path1)
train_path = path1 + root[1]
for files in sorted(os.listdir(train_path)):
    print(files)
    EMG = sio.loadmat(train_path+'/' + files)
    data = EMG['sampleEMG']
#     print(type(data))
# Out:
# 1.mat
# 10.mat
# 100.mat
# 101.mat
# 102.mat
# 103.mat
# 104.mat
# 105.mat
# 106.mat
# 107.mat
# 108.mat
# 109.mat
# 11.mat
# 110.mat
# 111.mat
# 112.mat
# 113.mat
# 114.mat
# 115.mat
# 116.mat
# 117.mat
# 118.mat
# 119.mat
# 12.mat
# 120.mat
# 121.mat
# 122.mat
# 123.mat
# 124.mat
# 125.mat
# 126.mat
# 127.mat
# 128.mat
# 129.mat
# 13.mat
# 130.mat
# 131.mat
# 132.mat
# 133.mat
# 134.mat
# 135.mat
# 136.mat
# 137.mat
# 138.mat
# 139.mat
# 14.mat
# 140.mat
# 141.mat
# 142.mat
# 143.mat
# 144.mat
# 145.mat
# 146.mat
# 147.mat
# 148.mat
# 149.mat
# 15.mat
# 150.mat
# 151.mat
# 152.mat
# 153.mat
# 154.mat
# 155.mat
# 156.mat
# 157.mat
# 158.mat
# 159.mat
# 16.mat
# 160.mat
# 161.mat
# 162.mat
# 163.mat
# 164.mat
# 165.mat
# 166.mat
# 167.mat
# 168.mat
# 169.mat
# 17.mat
# 170.mat
# 171.mat
# 172.mat
# 173.mat
# 174.mat
# 175.mat
# 176.mat
# 177.mat
# 178.mat
# 179.mat
# 18.mat
# 180.mat
# 181.mat
# 182.mat
# 183.mat
# 184.mat
# 185.mat
# 186.mat
# 187.mat
# 188.mat
# 189.mat
# 19.mat
# ...

# %%
data.shape
# Out:
# (300, 16)

# %%
a = {'a': [1 2 3]}
# Out:
#   File "<ipython-input-38-bd1344ead514>", line 1
#     a = {'a': [1 2 3]}
#                  ^
# SyntaxError: invalid syntax

# %%
train.keys().
# Out:
# dict_keys([1, 2, 3, 4, 5])

# %%
train.items()[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-19a6ee586cd3> in <module>
# ----> 1 train.items()[1]
#
# TypeError: 'dict_items' object is not subscriptable

# %%
a = {'a': 'tom', 'ben'}
